# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_classification

# %%
np.random.seed(0)

# %%
n = 10000

X, y = make_classification(n_samples = n, n_features = 2, n_redundant = 0, weights = [0.95])

Dados = pd.DataFrame(np.hstack((X, y.reshape(-1, 1))), columns = ['Renda', 'Exposição', 'Uso'])

Dados.head()
# Out:
#       Renda  Exposição  Uso
# 0 -1.315881   0.190348  0.0
# 1 -1.302528  -1.282953  0.0
# 2  0.244341   0.107240  0.0
# 3 -0.965250  -1.739436  0.0
# 4 -1.011645  -2.112210  0.0

# %%
plt.figure(figsize = (15, 5))

Grafico = sns.scatterplot(data = Dados, x = 'Renda', y = 'Exposição', hue = 'Uso', s = 75)

Grafico.spines['top'].set_visible(False)

Grafico.spines['right'].set_visible(False)

plt.show()

# %%
Dados.to_csv('Dados_Simulados.csv', index = False)
